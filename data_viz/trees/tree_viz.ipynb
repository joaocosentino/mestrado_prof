# %% [markdown]
# # Vizualiação de dados Hierárquicos

# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import os

# %% [markdown]
# ## Dataset - Stellantis eVOS Value Optimization

# %%
print(os.path.abspath('eVOs_Global.xlsx'))
# Out:
# /home/joaocosentino/mestrado_prof/data_viz/trees/eVOs_Global.xlsx

# %%
evos_df = pd.read_excel('eVOs_Global.xlsx')

# %%
columns_to_keep = ['Index',
       'Manager Group Code', 'Supplier Group Name','PSA / FCA Region',
       'Savings / Econs / Correction', 'Id_Idea', 'Metafunction', 'Function',
       'Technical Teams','Technical VO Group','Saving Type',
       'Short Description', 'CY Saving [€]',
       'avancement', 'Application Year', 'Application Month']
evos_df.drop(columns=[col for col in evos_df.columns if col not in columns_to_keep],inplace=True)

# %%
evos_df.dtypes
# Out:
# Index                           object
# Manager Group Code              object
# Supplier Group Name             object
# PSA / FCA Region                object
# Savings / Econs / Correction    object
# Id_Idea                         object
# Metafunction                    object
# Function                        object
# Technical Teams                 object
# Technical VO Group              object
# Saving Type                     object
# Short Description               object
# CY Saving [€]                    int64
# avancement                      object
# Application Year                 int64
# Application Month                int64
# dtype: object

# %%
evos_df.head()
# Out:
#          Index  Manager Group Code   Supplier Group Name PSA / FCA Region  \
# 0  JIRA_ACS-10  Purchasing Modules  CIE AUTOMOTIVE, S.A.           Europe
# 1   JIRA_AD-19      Interior Parts     ADLER PLASTIC SPA           Europe
# 2   JIRA_AD-36      Interior Parts     ADLER PLASTIC SPA           Europe
# 3   JIRA_AD-37      Interior Parts     ADLER PLASTIC SPA           Europe
# 4   JIRA_AD-38      Interior Parts     ADLER PLASTIC SPA           Europe
#
#   Savings / Econs / Correction      Id_Idea                Metafunction  \
# 0                      Savings  JIRA_ACS-10  BODY, CHASSIS and INTERIOR
# 1                      Savings   JIRA_AD-19  BODY, CHASSIS and INTERIOR
# 2                      Savings   JIRA_AD-36  BODY, CHASSIS and INTERIOR
# 3                      Savings   JIRA_AD-37  BODY, CHASSIS and INTERIOR
# 4                      Savings   JIRA_AD-38  BODY, CHASSIS and INTERIOR
#
#        Function                                Technical Teams  \
# 0  MECHATRONICS  Comfort, Visibility, Aero, Closure actuations
# 1     INTERIORS                  INT SOFT/HARD TRIM (ITVL+IHT)
# 2     INTERIORS                  INT SOFT/HARD TRIM (ITVL+IHT)
# 3     INTERIORS                  INT SOFT/HARD TRIM (ITVL+IHT)
# 4     INTERIORS                  INT SOFT/HARD TRIM (ITVL+IHT)
#
#   Technical VO Group   Saving Type  \
# 0     C15 - Sun roof       Ecotech
# 1         C19 - Trim       Ecotech
# 2         C19 - Trim  Ecomarketing
# 3         C19 - Trim       Ecotech
# 4         C19 - Trim  Ecomarketing
#
#                                    Short Description  CY Saving [€]  \
# 0           P24 - Velcro change on panoramic sunroof         -43470
# 1       P1UO - INSONO PASSAGE DE ROUE - Part Removal              0
# 2      P21 - Trunk Carpet : Binappe 900gm² to 550gm²        -300390
# 3  C4x - Dash inner Heavy Layer Eliminate the pat...         -54600
# 4  P51 - Parcel shelf : replace clip-elastique by...         -51320
#
#     avancement  Application Year  Application Month
# 0    Cancelled              2023                 10
# 1    Cancelled              2023                  1
# 2    Cancelled              2027                 10
# 3  Implemented              2023                  9
# 4    Cancelled              2027                 10

# %% [markdown]
# ### Filtrando dados não importantes

# %%
    evos_2023 = evos_df[evos_df["Application Year"]== 2023] # CY 2023
    evos_2023 = evos_2023[evos_2023['Savings / Econs / Correction'] == 'Savings'] #Savings only
    evos_2023 = evos_2023[evos_2023['avancement'] == "Implemented"]
    evos_2023 = evos_2023[evos_2023['Metafunction'].isin(['BODY, CHASSIS and INTERIOR','SOFTWARE X','PROPULSION SYSTEMS'])]
    evos_2023['CY Saving [€]'] = evos_2023['CY Saving [€]'].astype(str).str.replace("-",'')
    evos_2023['CY Saving [€]'] = evos_2023['CY Saving [€]'].astype(int)

# %%
evos_2023.head()
# Out:
#          Index Manager Group Code Supplier Group Name PSA / FCA Region  \
# 3   JIRA_AD-37     Interior Parts   ADLER PLASTIC SPA           Europe
# 19  JIRA_AD-62     Interior Parts   ADLER PLASTIC SPA           Europe
# 21  JIRA_AD-65     Interior Parts   ADLER PLASTIC SPA           Europe
# 22  JIRA_AD-66     Interior Parts   ADLER PLASTIC SPA           Europe
# 27  JIRA_AD-72     Interior Parts   ADLER PLASTIC SPA           Europe
#
#    Savings / Econs / Correction     Id_Idea                Metafunction  \
# 3                       Savings  JIRA_AD-37  BODY, CHASSIS and INTERIOR
# 19                      Savings  JIRA_AD-62  BODY, CHASSIS and INTERIOR
# 21                      Savings  JIRA_AD-65  BODY, CHASSIS and INTERIOR
# 22                      Savings  JIRA_AD-66  BODY, CHASSIS and INTERIOR
# 27                      Savings  JIRA_AD-72  BODY, CHASSIS and INTERIOR
#
#      Function                Technical Teams Technical VO Group   Saving Type  \
# 3   INTERIORS  INT SOFT/HARD TRIM (ITVL+IHT)         C19 - Trim       Ecotech
# 19  INTERIORS  INT SOFT/HARD TRIM (ITVL+IHT)         C19 - Trim  Supply Chain
# 21  INTERIORS  INT SOFT/HARD TRIM (ITVL+IHT)         C19 - Trim  Supply Chain
# 22  INTERIORS  INT SOFT/HARD TRIM (ITVL+IHT)         C19 - Trim  Supply Chain
# 27  INTERIORS  INT SOFT/HARD TRIM (ITVL+IHT)         C19 - Trim  Supply Chain
#
#                                     Short Description  CY Saving [€]  \
# 3   C4x - Dash inner Heavy Layer Eliminate the pat...          54600
# 19            packaging optimization INS AV ROUE  PAR           5360
# 21                             PACKAGING OPTIMISATION          29760
# 22  89_CJ_EN_Optimization_Packaging_Adler_98475288...          21970
# 27  Optimisation packaging tapis plancher AR, 9828...          18520
#
#      avancement  Application Year  Application Month
# 3   Implemented              2023                  9
# 19  Implemented              2023                  1
# 21  Implemented              2023                  5
# 22  Implemented              2023                  5
# 27  Implemented              2023                  7

# %%
evos_2023.drop(columns=['Id_Idea','Savings / Econs / Correction'],inplace=True)
evos_2023.head()
# Out:
#          Index Manager Group Code Supplier Group Name PSA / FCA Region  \
# 3   JIRA_AD-37     Interior Parts   ADLER PLASTIC SPA           Europe
# 19  JIRA_AD-62     Interior Parts   ADLER PLASTIC SPA           Europe
# 21  JIRA_AD-65     Interior Parts   ADLER PLASTIC SPA           Europe
# 22  JIRA_AD-66     Interior Parts   ADLER PLASTIC SPA           Europe
# 27  JIRA_AD-72     Interior Parts   ADLER PLASTIC SPA           Europe
#
#                   Metafunction   Function                Technical Teams  \
# 3   BODY, CHASSIS and INTERIOR  INTERIORS  INT SOFT/HARD TRIM (ITVL+IHT)
# 19  BODY, CHASSIS and INTERIOR  INTERIORS  INT SOFT/HARD TRIM (ITVL+IHT)
# 21  BODY, CHASSIS and INTERIOR  INTERIORS  INT SOFT/HARD TRIM (ITVL+IHT)
# 22  BODY, CHASSIS and INTERIOR  INTERIORS  INT SOFT/HARD TRIM (ITVL+IHT)
# 27  BODY, CHASSIS and INTERIOR  INTERIORS  INT SOFT/HARD TRIM (ITVL+IHT)
#
#    Technical VO Group   Saving Type  \
# 3          C19 - Trim       Ecotech
# 19         C19 - Trim  Supply Chain
# 21         C19 - Trim  Supply Chain
# 22         C19 - Trim  Supply Chain
# 27         C19 - Trim  Supply Chain
#
#                                     Short Description  CY Saving [€]  \
# 3   C4x - Dash inner Heavy Layer Eliminate the pat...          54600
# 19            packaging optimization INS AV ROUE  PAR           5360
# 21                             PACKAGING OPTIMISATION          29760
# 22  89_CJ_EN_Optimization_Packaging_Adler_98475288...          21970
# 27  Optimisation packaging tapis plancher AR, 9828...          18520
#
#      avancement  Application Year  Application Month
# 3   Implemented              2023                  9
# 19  Implemented              2023                  1
# 21  Implemented              2023                  5
# 22  Implemented              2023                  5
# 27  Implemented              2023                  7

# %%
fig = px.treemap(data_frame=evos_2023,path=[px.Constant('PSA / FCA Region'),'PSA / FCA Region','Saving Type',"Metafunction",'Function','Technical Teams','Technical VO Group'],values='CY Saving [€]')
fig.update_traces(root_color='lightgreen')
fig.update_layout(title_x=0.5)
# Out:
# <div>                            <div id="badefbc4-bead-4a06-a610-99f2afbc15d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("badefbc4-bead-4a06-a610-99f2afbc15d3")) {                    Plotly.newPlot(                        "badefbc4-bead-4a06-a610-99f2afbc15d3",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>CY Saving [\u20ac]=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["PSA / FCA Region/North America/Ecotech/PROPULSION SYSTEMS/PROPULSION SYSTEMS/TRANSMISSION & DRIVE LINE/8 Speed Transmission","PSA / FCA Region/North America/Ecotech/PROPULSION SYSTEMS/PROPULSION SYSTEMS/TRANSMISSION & DRIVE LINE/9 Speed Transmission","PSA / FCA Region/Europe/Ecotech/BODY, CHASSIS and INTERIOR/INTERIORS/INT SOFT/HARD TRIM (ITVL+IHT)/ACOUSTIC TREATMENTS","PSA / FCA Region/Europe/Other Drifts/BODY, CHASSIS and INTERIOR/INTERIORS/INT SOFT/HARD TRIM (ITVL+IHT)/ACOUSTIC TREATMENTS","PSA / FCA Region/Europe/Quality/BODY, CHASSIS and INTERIOR/INTERIORS/INT SOFT/HARD TRIM (ITVL+IHT)/ACOUSTIC TREATMENTS","PSA / FCA Region/Europe/Quality/SOFTWARE X/SOFTWARE X/HARDWARE ENGINEERING (EX EEME)/AIR CONDITIONING CONTROL","PSA / FCA Region/Europe/Ecotech/PROPULSION SYSTEMS/PROPULSION SYSTEMS/HVAC & ENGINE SYSTEMS/AIR INDUCTION","PSA / FCA Region/Europe/Quality/PROPULSION SYSTEMS/PROPULSION SYSTEMS/HVAC & ENGINE SYSTEMS/AIR INDUCTION","PSA / FCA Region/Europe/Quality/BODY, CHASSIS and INTERIOR/CHASSIS/CHASSIS FWD/AWD SUSPENSIONS PLUS RWD IF AGGREGATE/ALL WHEEL DRIVE TRASMISSION (DEACTIVATED)","PSA / FCA Region/Europe/Quality/BODY, CHASSIS and INTERIOR/MECHATRONICS/Commands, Suspensions, Sensors/AUTOMATIC TRANSMISSION SHIFTER","PSA / FCA Region/North America/Other Drifts/BODY, CHASSIS and INTERIOR/CHASSIS/Mechatronics Chassis/Active Suspension","PSA / FCA Region/North America/Ecotech/BODY, CHASSIS and INTERIOR/CHASSIS/CHASSIS BRAKING SYSTEMS/Actuation Systems**","PSA / FCA Region/North America/Ecomarketing/BODY, CHASSIS and INTERIOR/BODY/BODY EXTERIOR TRIM/Aero / Cladding (FEM)","PSA / FCA Region/North America/Ecotech/BODY, CHASSIS and INTERIOR/BODY/BODY EXTERIOR TRIM/Aero / Cladding (FEM)","PSA / FCA Region/North America/Ecotech/PROPULSION SYSTEMS/PROPULSION SYSTEMS/HVAC & ENGINE SYSTEMS/Aftertreatment","PSA / FCA Region/North America/Ecomarketing/BODY, CHASSIS and INTERIOR/INTERIORS/INT SEAT (ISC+ISSC)/Air Bags*","PSA / FCA Region/North America/Ecotech/BODY, CHASSIS and INTERIOR/INTERIORS/INT SEAT (ISC+ISSC)/Air Bags*","PSA / FCA Region/North America/Ecotech/SOFTWARE X/SOFTWARE X/EE PROPULSION SYSTEMS/Alternators (EEPS)","PSA / FCA Region/Europe/Ecotech/SOFTWARE X/SOFTWARE X/EE PROPULSION SYSTEMS/BATTERY","PSA / FCA Region/Europe/Ecotech/PROPULSION SYSTEMS/PROPULSION SYSTEMS/BATTERY CELLS, MODULES AND PACKS/BATTERY STORAGE SYSTEM","PSA / FCA Region/Europe/Product Savings/PROPULSION SYSTEMS/PROPULSION SYSTEMS/BATTERY CELLS, MODULES AND PACKS/BATTERY STORAGE SYSTEM","PSA / FCA Region/Europe/Ecomarketing/SOFTWARE X/SOFTWARE X/HARDWARE ENGINEERING (EX EEME)/BODY CONTROL AND DIAGNOSTICS","PSA / FCA Region/Europe/Ecotech/SOFTWARE X/SOFTWARE X/HARDWARE ENGINEERING (EX EEME)/BODY CONTROL AND DIAGNOSTICS","PSA / FCA Region/Europe/Product Savings/SOFTWARE X/SOFTWARE X/HARDWARE ENGINEERING (EX EEME)/BODY CONTROL AND DIAGNOSTICS","PSA / FCA Region/Europe/Quality/SOFTWARE X/SOFTWARE X/HARDWARE ENGINEERING (EX EEME)/BODY CONTROL AND DIAGNOSTICS","PSA / FCA Region/Europe/Ecomarketing/BODY, CHASSIS and INTERIOR/BODY/BODY UPPERBODY BIW/BODY SIDE STRUCTURE","PSA / FCA Region/Europe/Ecotech/BODY, CHASSIS and INTERIOR/BODY/BODY UPPERBODY BIW/BODY SIDE STRUCTURE","PSA / FCA Region/Europe/Quality/BODY, CHASSIS and INTERIOR/BODY/BODY UPPERBODY BIW/BO ...
